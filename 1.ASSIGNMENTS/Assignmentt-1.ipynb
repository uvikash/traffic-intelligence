# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjana3113/Smart-Internz/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrame with 4 features and observations

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({'Name':['sam','priya','sarah','shyam'],'Maths':[95,86,55,77],'English':[88,77,51,25],'Computer':[88,85,77,65],'science':[87,65,95,75]})
df
# Out:
#     Name  Maths  English  Computer  science
# 0    sam     95       88        88       87
# 1  priya     86       77        85       65
# 2  sarah     55       51        77       95
# 3  shyam     77       25        65       75

# %% [markdown]
# # Changing column names.

# %%
df.columns =['Name','Random_value 1','Random_value 2','Random_value 3','Random_value 4']
df
# Out:
#     Name  Random_value 1  Random_value 2  Random_value 3  Random_value 4
# 0    sam              95              88              88              87
# 1  priya              86              77              85              65
# 2  sarah              55              51              77              95
# 3  shyam              77              25              65              75

# %% [markdown]
# # Descriptive Statistics.

# %%
df.describe()
# Out:
#        Random_value 1  Random_value 2  Random_value 3  Random_value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        78.250000       60.250000       78.750000       80.500000
# std         17.153717       28.158776       10.275375       13.203535
# min         55.000000       25.000000       65.000000       65.000000
# 25%         71.500000       44.500000       74.000000       72.500000
# 50%         81.500000       64.000000       81.000000       81.000000
# 75%         88.250000       79.750000       85.750000       89.000000
# max         95.000000       88.000000       88.000000       95.000000

# %% [markdown]
# # Null Values

# %%
df.isnull().any()
# Out:
# Name              False
# Random_value 1    False
# Random_value 2    False
# Random_value 3    False
# Random_value 4    False
# dtype: bool

# %% [markdown]
# # Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Random_value 1  4 non-null      int64
#  2   Random_value 2  4 non-null      int64
#  3   Random_value 3  4 non-null      int64
#  4   Random_value 4  4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# # Location and Ilocation methods

# %%
df.iloc[:,2:4]
# Out:
#    Random_value 2  Random_value 3
# 0              88              88
# 1              77              85
# 2              51              77
# 3              25              65

# %%
df.loc[:,'Random_value 2':'Random_value 3']
# Out:
#    Random_value 2  Random_value 3
# 0              88              88
# 1              77              85
# 2              51              77
# 3              25              65
